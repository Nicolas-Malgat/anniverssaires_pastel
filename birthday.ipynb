# %%
import pandas as pd
import numpy as np

df = pd.read_csv('pastels.csv', sep=';')
df.birthday = pd.to_datetime(df.birthday, format='%d/%m/%Y')

df.head(5)
# Out:
#         name   birthday
# 0    Nicolas 2021-01-13
# 1    Estelle 2021-02-18
# 2  Alexandre 2021-03-18
# 3      Laura 2021-04-06
# 4     Alexis 2021-06-01

# %%
from datetime import datetime

now = pd.Timestamp(datetime.now())
ajd = "Aujourd'hui"
df = df.append({'name': ajd, 'birthday': now}, ignore_index=True)

# %%
# import plotly.express as px

# df['birthday_day'] = [date.day for date in df.birthday]
# df['birthday_month'] = [date.month for date in df.birthday]

# df.sort_values(by='birthday_month', inplace=True, ascending=False)

# fig = px.scatter(df, x="birthday_month", y='birthday_day', text='name')

# fig.update_layout(
#     xaxis = dict(
#         tickmode = 'linear',
#         tick0 = 1,
#         dtick = 1
#     )
# )

# fig.update_traces(
#     textposition='top center'
# )

# fig.show()
# fig.write_html('birthday_scatter.html')

# %%
import datetime
import plotly.graph_objs as go
import numpy as np

import locale
locale.setlocale(locale.LC_ALL, 'fr_FR')
import calendar

year = datetime.datetime.now().year

d1 = datetime.date(year, 1, 1)
d2 = datetime.date(year, 12, 31)
delta = d2 - d1

dates_in_year = [d1 + datetime.timedelta(i) for i in range(delta.days+1)]
weekdays_in_year = [i.weekday() for i in dates_in_year]
weeknumber_of_dates = [i.strftime("%G%V")[4:] for i in dates_in_year]

z = np.zeros(len(dates_in_year))
text = ['' for i in dates_in_year]

for _, row in df.iterrows():
    if row['name'] == ajd:
        z[row.birthday.day_of_year] = 0.5
    else:
        z[row.birthday.day_of_year] = True

    information_hover = f"""{row['name']}: {calendar.day_name[row.birthday.weekday()]} {row.birthday.day} {calendar.month_name[row.birthday.month]}"""
    text[row.birthday.day_of_year] = information_hover

colorscale = [[False, '#172a16'], [0.5, '#ddecdc'], [True, '#5fa95b']]

data = [
    go.Heatmap(
        x = weeknumber_of_dates,
        y = weekdays_in_year,
        z = z,
        text=text,
        hoverinfo="text",
        xgap=3, # this
        ygap=3, # and this is used to make the grid-like apperance
        showscale=False,
        colorscale=colorscale
    )
]
layout = go.Layout(
        title='Anniversaires Pastel',
        height=280,
    yaxis=dict(
        showline = False, showgrid = False, zeroline = False,
        tickmode="array",
        ticktext=["Dimanche", "Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi"],
        tickvals=[0,1,2,3,4,5,6],
    ),
    xaxis=dict(
        showline = False, showgrid = False, zeroline = False,
    ),
        font={'size':10},
        plot_bgcolor=('#050a05'),
        margin = dict(t=45),
        template='plotly_dark'
)

fig = go.Figure(data=data, layout=layout)
fig.show()
fig.write_html('birthday_heatmap.html')

# %%
# !jupyter nbconvert --to html birthday.ipynb
# Out:
# [NbConvertApp] Converting notebook birthday.ipynb to html
# D:\ana_conda\envs\sandbox\lib\site-packages\nbconvert\filters\datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/vnd.plotly.v1+json']) is not able to be represented.
#   mimetypes=output.keys())
# [NbConvertApp] Writing 585934 bytes to birthday.html
